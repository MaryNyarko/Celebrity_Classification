# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/beyonce.jpg')
img.shape
# Out:
# (300, 400, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (300, 400)

# %%
gray
# Out:
# array([[22, 23, 24, ..., 20, 19, 19],
#        [22, 22, 23, ..., 20, 19, 19],
#        [21, 21, 22, ..., 20, 19, 19],
#        ...,
#        [18, 19, 20, ..., 10, 10, 10],
#        [19, 20, 20, ..., 11, 11, 11],
#        [19, 20, 21, ..., 11, 11, 11]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[139,  75, 148, 148]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (139, 75, 148, 148)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (148, 148, 3)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is not None:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                            return roi_color

# %%
original_image = cv2.imread('./test_images/beyonce.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/beyonce.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/test2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/test2.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Zendaya',
#  './dataset/BillieEilish ',
#  './dataset/LebronJames',
#  './dataset/DonaldTrump',
#  './dataset/WillSmith',
#  './dataset/KimKardashian',
#  './dataset/Beyonce',
#  './dataset/Cardi_B',
#  './dataset/KanyeWest',
#  './dataset/cropped']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Zendaya
# Generating cropped images in folder:  ./dataset/cropped/Zendaya
# libpng warning: iCCP: known incorrect sRGB profile
# BillieEilish
# Generating cropped images in folder:  ./dataset/cropped/BillieEilish
# LebronJames
# Generating cropped images in folder:  ./dataset/cropped/LebronJames
# libpng warning: iCCP: known incorrect sRGB profile
# DonaldTrump
# Generating cropped images in folder:  ./dataset/cropped/DonaldTrump
# WillSmith
# Generating cropped images in folder:  ./dataset/cropped/WillSmith
# libpng warning: iCCP: known incorrect sRGB profile
# KimKardashian
# Generating cropped images in folder:  ./dataset/cropped/KimKardashian
# Beyonce
# Generating cropped images in folder:  ./dataset/cropped/Beyonce
# Cardi_B
# Generating cropped images in folder:  ./dataset/cropped/Cardi_B
# KanyeWest
# Generating cropped images in folder:  ./dataset/cropped/KanyeWest
# cropped

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'Zendaya': ['./dataset/cropped/Zendaya/Zendaya1.png',
#   './dataset/cropped/Zendaya/Zendaya2.png',
#   './dataset/cropped/Zendaya/Zendaya3.png',
#   './dataset/cropped/Zendaya/Zendaya4.png',
#   './dataset/cropped/Zendaya/Zendaya5.png',
#   './dataset/cropped/Zendaya/Zendaya6.png',
#   './dataset/cropped/Zendaya/Zendaya7.png',
#   './dataset/cropped/Zendaya/Zendaya8.png',
#   './dataset/cropped/Zendaya/Zendaya9.png',
#   './dataset/cropped/Zendaya/Zendaya10.png',
#   './dataset/cropped/Zendaya/Zendaya11.png',
#   './dataset/cropped/Zendaya/Zendaya12.png',
#   './dataset/cropped/Zendaya/Zendaya13.png',
#   './dataset/cropped/Zendaya/Zendaya14.png',
#   './dataset/cropped/Zendaya/Zendaya15.png',
#   './dataset/cropped/Zendaya/Zendaya16.png',
#   './dataset/cropped/Zendaya/Zendaya17.png',
#   './dataset/cropped/Zendaya/Zendaya18.png',
#   './dataset/cropped/Zendaya/Zendaya19.png',
#   './dataset/cropped/Zendaya/Zendaya20.png',
#   './dataset/cropped/Zendaya/Zendaya21.png',
#   './dataset/cropped/Zendaya/Zendaya22.png',
#   './dataset/cropped/Zendaya/Zendaya23.png',
#   './dataset/cropped/Zendaya/Zendaya24.png',
#   './dataset/cropped/Zendaya/Zendaya25.png',
#   './dataset/cropped/Zendaya/Zendaya26.png',
#   './dataset/cropped/Zendaya/Zendaya27.png',
#   './dataset/cropped/Zendaya/Zendaya28.png',
#   './dataset/cropped/Zendaya/Zendaya29.png',
#   './dataset/cropped/Zendaya/Zendaya30.png',
#   './dataset/cropped/Zendaya/Zendaya31.png',
#   './dataset/cropped/Zendaya/Zendaya32.png',
#   './dataset/cropped/Zendaya/Zendaya33.png',
#   './dataset/cropped/Zendaya/Zendaya34.png',
#   './dataset/cropped/Zendaya/Zendaya35.png',
#   './dataset/cropped/Zendaya/Zendaya36.png',
#   './dataset/cropped/Zendaya/Zendaya37.png',
#   './dataset/cropped/Zendaya/Zendaya38.png',
#   './dataset/cropped/Zendaya/Zendaya39.png',
#   './dataset/cropped/Zendaya/Zendaya40.png',
#   './dataset/cropped/Zendaya/Zendaya41.png',
#   './dataset/cropped/Zendaya/Zendaya42.png',
#   './dataset/cropped/Zendaya/Zendaya43.png',
#   './dataset/cropped/Zendaya/Zendaya44.png',
#   './dataset/cropped/Zendaya/Zendaya45.png',
#   './dataset/cropped/Zendaya/Zendaya46.png',
#   './dataset/cropped/Zendaya/Zendaya47.png',
#   './dataset/cropped/Zendaya/Zendaya48.png',
#   './dataset/cropped/Zendaya/Zendaya49.png',
#   './dataset/cropped/Zendaya/Zendaya50.png',
#   './dataset/cropped/Zendaya/Zendaya51.png',
#   './dataset/cropped/Zendaya/Zendaya52.png',
#   './dataset/cropped/Zendaya/Zendaya53.png',
#   './dataset/cropped/Zendaya/Zendaya54.png',
#   './dataset/cropped/Zendaya/Zendaya55.png',
#   './dataset/cropped/Zendaya/Zendaya56.png',
#   './dataset/cropped/Zendaya/Zendaya57.png',
#   './dataset/cropped/Zendaya/Zendaya58.png',
#   './dataset/cropped/Zendaya/Zendaya59.png',
#   './dataset/cropped/Zendaya/Zendaya60.png',
#   './dataset/cropped/Zendaya/Zendaya61.png',
#   './dataset/cropped/Zendaya/Zendaya62.png',
#   './dataset/cropped/Zendaya/Zendaya63.png',
#   './dataset/cropped/Zendaya/Zendaya64.png',
#   './dataset/cropped/Zendaya/Zendaya65.png',
#   './dataset/cropped/Zendaya/Zendaya66.png',
#   './dataset/cropped/Zendaya/Zendaya67.png',
#   './dataset/cropped/Zendaya/Zendaya68.png',
#   './dataset/cropped/Zendaya/Zendaya69.png',
#   './dataset/cropped/Zendaya/Zendaya70.png',
#   './dataset/cropped/Zendaya/Zendaya71.png',
#   './dataset/cropped/Zendaya/Zendaya72.png',
#   './dataset/cropped/Zendaya/Zendaya73.png',
#   './dataset/cropped/Zendaya/Zendaya74.png',
#   './dataset/cropped/Zendaya/Zendaya75.png',
#   './dataset/cropped/Zendaya/Zendaya76.png',
#   './dataset/cropped/Zendaya/Zendaya77.png',
#   './dataset/cropped/Zendaya/Zendaya78.png',
#   './dataset/cropped/Zendaya/Zendaya79.png',
#   './dataset/cropped/Zendaya/Zendaya80.png',
#   './dataset/cropped/Zendaya/Zendaya81.png',
#   './dataset/cropped/Zendaya/Zendaya82.png',
#   './dataset/cropped/Zendaya/Zendaya83.png',
#   './dataset/cropped/Zendaya/Zendaya84.png',
#   './dataset/cropped/Zendaya/Zendaya85.png',
#   './dataset/cropped/Zendaya/Zendaya86.png',
#   './dataset/cropped/Zendaya/Zendaya87.png',
#   './dataset/cropped/Zendaya/Zendaya88.png',
#   './dataset/cropped/Zendaya/Zendaya89.png',
#   './dataset/cropped/Zendaya/Zendaya90.png',
#   './dataset/cropped/Zendaya/Zendaya91.png',
#   './dataset/cropped/Zendaya/Zendaya92.png',
#   './dataset/cropped/Zendaya/Zendaya93.png',
#   './dataset/cropped/Zendaya/Zendaya94.png',
#   './dataset/cropped/Zendaya/Zendaya95.png',
#   './dataset/cropped/Zendaya/Zendaya96.png',
#   './dataset/cropped/Zendaya/Zendaya97.png',
#   './dataset/cropped/Zendaya/Zendaya98.png',
#   './dataset/cropped/Zendaya/Zendaya99.png',
#   './dataset/cropped/Zendaya/Zendaya100.png',
#   './dataset/cropped/Zendaya/Zendaya101.png',
#   './dataset/cropped/Zendaya/Zendaya102.png',
#   './dataset/cropped/Zendaya/Zendaya103.png',
#   './dataset/cropped/Zendaya/Zendaya104.png',
#   './dataset/cropped/Zendaya/Zendaya105.png',
#   './dataset/cropped/Zendaya/Zendaya106.png',
#   './dataset/cropped/Zendaya/Zendaya107.png',
#   './dataset/cropped/Zendaya/Zendaya108.png',
#   './dataset/cropped/Zendaya/Zendaya109.png',
#   './dataset/cropped/Zendaya/Zendaya110.png',
#   './dataset/cropped/Zendaya/Zendaya111.png',
#   './dataset/cropped/Zendaya/Zendaya112.png',
#   './dataset/cropped/Zendaya/Zendaya113.png',
#   './dataset/cropped/Zendaya/Zendaya114.png',
#   './dataset/cropped/Zendaya/Zendaya115.png',
#   './dataset/cropped/Zendaya/Zendaya116.png',
#   './dataset/cropped/Zendaya/Zendaya117.png',
#   './dataset/cropped/Zendaya/Zendaya118.png',
#   './dataset/cropped/Zendaya/Zendaya119.png',
#   './dataset/cropped/Zendaya/Zendaya120.png'],
#  'BillieEilish ': ['./dataset/cropped/BillieEilish /BillieEilish 1.png',
#   './dataset/cropped/BillieEilish /BillieEilish 2.png',
#   './dataset/cropped/BillieEilish /BillieEilish 3.png',
#   './dataset/cropped/BillieEilish /BillieEilish 4.png',
#   './dataset/cropped/BillieEilish /BillieEilish 5.png',
#   './dataset/cropped/BillieEilish /BillieEilish 6.png',
#   './dataset/cropped/BillieEilish /BillieEilish 7.png',
#   './dataset/cropped/BillieEilish /BillieEilish 8.png',
#   './dataset/cropped/BillieEilish /BillieEilish 9.png',
#   './dataset/cropped/BillieEilish /BillieEilish 10.png',
#   './dataset/cropped/BillieEilish /BillieEilish 11.png',
#   './dataset/cropped/BillieEilish /BillieEilish 12.png',
#   './dataset/cropped/BillieEilish /BillieEilish 13.png',
#   './dataset/cropped/BillieEilish /BillieEilish 14.png',
#   './dataset/cropped/BillieEilish /BillieEilish 15.png',
#   './dataset/cropped/BillieEilish /BillieEilish 16.png',
#   './dataset/cropped/BillieEilish /BillieEilish 17.png',
#   './dataset/cropped/BillieEilish /BillieEilish 18.png',
#   './dataset/cropped/BillieEilish /BillieEilish 19.png',
#   './dataset/cropped/BillieEilish /BillieEilish 20.png',
#   './dataset/cropped/BillieEilish /BillieEilish 21.png',
#   './dataset/cropped/BillieEilish /BillieEilish 22.png',
#   './dataset/cropped/BillieEilish /BillieEilish 23.png',
#   './dataset/cropped/BillieEilish /BillieEilish 24.png',
#   './dataset/cropped/BillieEilish /BillieEilish 25.png',
#   './dataset/cropped/BillieEilish /BillieEilish 26.png',
#   './dataset/cropped/BillieEilish /BillieEilish 27.png',
#   './dataset/cropped/BillieEilish /BillieEilish 28.png',
#   './dataset/cropped/BillieEilish /BillieEilish 29.png',
#   './dataset/cropped/BillieEilish /BillieEilish 30.png',
#   './dataset/cropped/BillieEilish /BillieEilish 31.png',
#   './dataset/cropped/BillieEilish /BillieEilish 32.png',
#   './dataset/cropped/BillieEilish /BillieEilish 33.png',
#   './dataset/cropped/BillieEilish /BillieEilish 34.png',
#   './dataset/cropped/BillieEilish /BillieEilish 35.png',
#   './dataset/cropped/BillieEilish /BillieEilish 36.png',
#   './dataset/cropped/BillieEilish /BillieEilish 37.png'],
#  'LebronJames': ['./dataset/cropped/LebronJames/LebronJames1.png',
#   './dataset/cropped/LebronJames/LebronJames2.png',
#   './dataset/cropped/LebronJames/LebronJames3.png',
#   './dataset/cropped/LebronJames/LebronJames4.png',
#   './dataset/cropped/LebronJames/LebronJames5.png',
#   './dataset/cropped/LebronJames/LebronJames6.png',
#   './dataset/cropped/LebronJames/LebronJames7.png',
#   './dataset/cropped/LebronJames/LebronJames8.png',
#   './dataset/cropped/LebronJames/LebronJames9.png',
#   './dataset/cropped/LebronJames/LebronJames10.png',
#   './dataset/cropped/LebronJames/LebronJames11.png',
#   './dataset/cropped/LebronJames/LebronJames12.png',
#   './dataset/cropped/LebronJames/LebronJames13.png',
#   './dataset/cropped/LebronJames/LebronJames14.png',
#   './dataset/cropped/LebronJames/LebronJames15.png',
#   './dataset/cropped/LebronJames/LebronJames16.png',
#   './dataset/cropped/LebronJames/LebronJames17.png',
#   './dataset/cropped/LebronJames/LebronJames18.png',
#   './dataset/cropped/LebronJames/LebronJames19.png',
#   './dataset/cropped/LebronJames/LebronJames20.png',
#   './dataset/cropped/LebronJames/LebronJames21.png',
#   './dataset/cropped/LebronJames/LebronJames22.png',
#   './dataset/cropped/LebronJames/LebronJames23.png',
#   './dataset/cropped/LebronJames/LebronJames24.png',
#   './dataset/cropped/LebronJames/LebronJames25.png',
#   './dataset/cropped/LebronJames/LebronJames26.png',
#   './dataset/cropped/LebronJames/LebronJames27.png',
#   './dataset/cropped/LebronJames/LebronJames28.png',
#   './dataset/cropped/LebronJames/LebronJames29.png',
#   './dataset/cropped/LebronJames/LebronJames30.png',
#   './dataset/cropped/LebronJames/LebronJames31.png',
#   './dataset/cropped/LebronJames/LebronJames32.png',
#   './dataset/cropped/LebronJames/LebronJames33.png',
#   './dataset/cropped/LebronJames/LebronJames34.png',
#   './dataset/cropped/LebronJames/LebronJames35.png',
#   './dataset/cropped/LebronJames/LebronJames36.png'],
#  'DonaldTrump': ['./dataset/cropped/DonaldTrump/DonaldTrump1.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump2.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump3.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump4.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump5.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump6.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump7.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump8.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump9.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump10.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump11.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump12.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump13.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump14.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump15.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump16.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump17.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump18.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump19.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump20.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump21.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump22.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump23.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump24.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump25.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump26.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump27.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump28.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump29.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump30.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump31.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump32.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump33.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump34.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump35.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump36.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump37.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump38.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump39.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump40.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump41.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump42.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump43.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump44.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump45.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump46.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump47.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump48.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump49.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump50.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump51.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump52.png'],
#  'WillSmith': ['./dataset/cropped/WillSmith/WillSmith1.png',
#   './dataset/cropped/WillSmith/WillSmith2.png',
#   './dataset/cropped/WillSmith/WillSmith3.png',
#   './dataset/cropped/WillSmith/WillSmith4.png',
#   './dataset/cropped/WillSmith/WillSmith5.png',
#   './dataset/cropped/WillSmith/WillSmith6.png',
#   './dataset/cropped/WillSmith/WillSmith7.png',
#   './dataset/cropped/WillSmith/WillSmith8.png',
#   './dataset/cropped/WillSmith/WillSmith9.png',
#   './dataset/cropped/WillSmith/WillSmith10.png',
#   './dataset/cropped/WillSmith/WillSmith11.png',
#   './dataset/cropped/WillSmith/WillSmith12.png',
#   './dataset/cropped/WillSmith/WillSmith13.png',
#   './dataset/cropped/WillSmith/WillSmith14.png',
#   './dataset/cropped/WillSmith/WillSmith15.png',
#   './dataset/cropped/WillSmith/WillSmith16.png',
#   './dataset/cropped/WillSmith/WillSmith17.png',
#   './dataset/cropped/WillSmith/WillSmith18.png',
#   './dataset/cropped/WillSmith/WillSmith19.png',
#   './dataset/cropped/WillSmith/WillSmith20.png',
#   './dataset/cropped/WillSmith/WillSmith21.png',
#   './dataset/cropped/WillSmith/WillSmith22.png',
#   './dataset/cropped/WillSmith/WillSmith23.png',
#   './dataset/cropped/WillSmith/WillSmith24.png',
#   './dataset/cropped/WillSmith/WillSmith25.png',
#   './dataset/cropped/WillSmith/WillSmith26.png',
#   './dataset/cropped/WillSmith/WillSmith27.png',
#   './dataset/cropped/WillSmith/WillSmith28.png',
#   './dataset/cropped/WillSmith/WillSmith29.png',
#   './dataset/cropped/WillSmith/WillSmith30.png',
#   './dataset/cropped/WillSmith/WillSmith31.png',
#   './dataset/cropped/WillSmith/WillSmith32.png',
#   './dataset/cropped/WillSmith/WillSmith33.png',
#   './dataset/cropped/WillSmith/WillSmith34.png',
#   './dataset/cropped/WillSmith/WillSmith35.png',
#   './dataset/cropped/WillSmith/WillSmith36.png',
#   './dataset/cropped/WillSmith/WillSmith37.png',
#   './dataset/cropped/WillSmith/WillSmith38.png',
#   './dataset/cropped/WillSmith/WillSmith39.png',
#   './dataset/cropped/WillSmith/WillSmith40.png',
#   './dataset/cropped/WillSmith/WillSmith41.png',
#   './dataset/cropped/WillSmith/WillSmith42.png',
#   './dataset/cropped/WillSmith/WillSmith43.png',
#   './dataset/cropped/WillSmith/WillSmith44.png',
#   './dataset/cropped/WillSmith/WillSmith45.png',
#   './dataset/cropped/WillSmith/WillSmith46.png',
#   './dataset/cropped/WillSmith/WillSmith47.png',
#   './dataset/cropped/WillSmith/WillSmith48.png',
#   './dataset/cropped/WillSmith/WillSmith49.png',
#   './dataset/cropped/WillSmith/WillSmith50.png',
#   './dataset/cropped/WillSmith/WillSmith51.png',
#   './dataset/cropped/WillSmith/WillSmith52.png',
#   './dataset/cropped/WillSmith/WillSmith53.png',
#   './dataset/cropped/WillSmith/WillSmith54.png',
#   './dataset/cropped/WillSmith/WillSmith55.png',
#   './dataset/cropped/WillSmith/WillSmith56.png',
#   './dataset/cropped/WillSmith/WillSmith57.png',
#   './dataset/cropped/WillSmith/WillSmith58.png',
#   './dataset/cropped/WillSmith/WillSmith59.png',
#   './dataset/cropped/WillSmith/WillSmith60.png',
#   './dataset/cropped/WillSmith/WillSmith61.png',
#   './dataset/cropped/WillSmith/WillSmith62.png',
#   './dataset/cropped/WillSmith/WillSmith63.png',
#   './dataset/cropped/WillSmith/WillSmith64.png',
#   './dataset/cropped/WillSmith/WillSmith65.png',
#   './dataset/cropped/WillSmith/WillSmith66.png',
#   './dataset/cropped/WillSmith/WillSmith67.png',
#   './dataset/cropped/WillSmith/WillSmith68.png',
#   './dataset/cropped/WillSmith/WillSmith69.png',
#   './dataset/cropped/WillSmith/WillSmith70.png',
#   './dataset/cropped/WillSmith/WillSmith71.png',
#   './dataset/cropped/WillSmith/WillSmith72.png',
#   './dataset/cropped/WillSmith/WillSmith73.png',
#   './dataset/cropped/WillSmith/WillSmith74.png',
#   './dataset/cropped/WillSmith/WillSmith75.png',
#   './dataset/cropped/WillSmith/WillSmith76.png',
#   './dataset/cropped/WillSmith/WillSmith77.png',
#   './dataset/cropped/WillSmith/WillSmith78.png',
#   './dataset/cropped/WillSmith/WillSmith79.png',
#   './dataset/cropped/WillSmith/WillSmith80.png',
#   './dataset/cropped/WillSmith/WillSmith81.png',
#   './dataset/cropped/WillSmith/WillSmith82.png',
#   './dataset/cropped/WillSmith/WillSmith83.png',
#   './dataset/cropped/WillSmith/WillSmith84.png',
#   './dataset/cropped/WillSmith/WillSmith85.png',
#   './dataset/cropped/WillSmith/WillSmith86.png',
#   './dataset/cropped/WillSmith/WillSmith87.png',
#   './dataset/cropped/WillSmith/WillSmith88.png',
#   './dataset/cropped/WillSmith/WillSmith89.png',
#   './dataset/cropped/WillSmith/WillSmith90.png',
#   './dataset/cropped/WillSmith/WillSmith91.png',
#   './dataset/cropped/WillSmith/WillSmith92.png',
#   './dataset/cropped/WillSmith/WillSmith93.png',
#   './dataset/cropped/WillSmith/WillSmith94.png',
#   './dataset/cropped/WillSmith/WillSmith95.png',
#   './dataset/cropped/WillSmith/WillSmith96.png',
#   './dataset/cropped/WillSmith/WillSmith97.png',
#   './dataset/cropped/WillSmith/WillSmith98.png',
#   './dataset/cropped/WillSmith/WillSmith99.png',
#   './dataset/cropped/WillSmith/WillSmith100.png',
#   './dataset/cropped/WillSmith/WillSmith101.png',
#   './dataset/cropped/WillSmith/WillSmith102.png',
#   './dataset/cropped/WillSmith/WillSmith103.png',
#   './dataset/cropped/WillSmith/WillSmith104.png',
#   './dataset/cropped/WillSmith/WillSmith105.png',
#   './dataset/cropped/WillSmith/WillSmith106.png',
#   './dataset/cropped/WillSmith/WillSmith107.png',
#   './dataset/cropped/WillSmith/WillSmith108.png',
#   './dataset/cropped/WillSmith/WillSmith109.png',
#   './dataset/cropped/WillSmith/WillSmith110.png',
#   './dataset/cropped/WillSmith/WillSmith111.png',
#   './dataset/cropped/WillSmith/WillSmith112.png',
#   './dataset/cropped/WillSmith/WillSmith113.png',
#   './dataset/cropped/WillSmith/WillSmith114.png',
#   './dataset/cropped/WillSmith/WillSmith115.png',
#   './dataset/cropped/WillSmith/WillSmith116.png',
#   './dataset/cropped/WillSmith/WillSmith117.png',
#   './dataset/cropped/WillSmith/WillSmith118.png',
#   './dataset/cropped/WillSmith/WillSmith119.png',
#   './dataset/cropped/WillSmith/WillSmith120.png',
#   './dataset/cropped/WillSmith/WillSmith121.png',
#   './dataset/cropped/WillSmith/WillSmith122.png',
#   './dataset/cropped/WillSmith/WillSmith123.png',
#   './dataset/cropped/WillSmith/WillSmith124.png',
#   './dataset/cropped/WillSmith/WillSmith125.png',
#   './dataset/cropped/WillSmith/WillSmith126.png',
#   './dataset/cropped/WillSmith/WillSmith127.png',
#   './dataset/cropped/WillSmith/WillSmith128.png',
#   './dataset/cropped/WillSmith/WillSmith129.png',
#   './dataset/cropped/WillSmith/WillSmith130.png',
#   './dataset/cropped/WillSmith/WillSmith131.png',
#   './dataset/cropped/WillSmith/WillSmith132.png'],
#  'KimKardashian': ['./dataset/cropped/KimKardashian/KimKardashian1.png',
#   './dataset/cropped/KimKardashian/KimKardashian2.png',
#   './dataset/cropped/KimKardashian/KimKardashian3.png',
#   './dataset/cropped/KimKardashian/KimKardashian4.png',
#   './dataset/cropped/KimKardashian/KimKardashian5.png',
#   './dataset/cropped/KimKardashian/KimKardashian6.png',
#   './dataset/cropped/KimKardashian/KimKardashian7.png',
#   './dataset/cropped/KimKardashian/KimKardashian8.png',
#   './dataset/cropped/KimKardashian/KimKardashian9.png',
#   './dataset/cropped/KimKardashian/KimKardashian10.png',
#   './dataset/cropped/KimKardashian/KimKardashian11.png',
#   './dataset/cropped/KimKardashian/KimKardashian12.png',
#   './dataset/cropped/KimKardashian/KimKardashian13.png',
#   './dataset/cropped/KimKardashian/KimKardashian14.png',
#   './dataset/cropped/KimKardashian/KimKardashian15.png',
#   './dataset/cropped/KimKardashian/KimKardashian16.png',
#   './dataset/cropped/KimKardashian/KimKardashian17.png',
#   './dataset/cropped/KimKardashian/KimKardashian18.png',
#   './dataset/cropped/KimKardashian/KimKardashian19.png',
#   './dataset/cropped/KimKardashian/KimKardashian20.png',
#   './dataset/cropped/KimKardashian/KimKardashian21.png',
#   './dataset/cropped/KimKardashian/KimKardashian22.png',
#   './dataset/cropped/KimKardashian/KimKardashian23.png',
#   './dataset/cropped/KimKardashian/KimKardashian24.png',
#   './dataset/cropped/KimKardashian/KimKardashian25.png',
#   './dataset/cropped/KimKardashian/KimKardashian26.png',
#   './dataset/cropped/KimKardashian/KimKardashian27.png',
#   './dataset/cropped/KimKardashian/KimKardashian28.png',
#   './dataset/cropped/KimKardashian/KimKardashian29.png',
#   './dataset/cropped/KimKardashian/KimKardashian30.png',
#   './dataset/cropped/KimKardashian/KimKardashian31.png',
#   './dataset/cropped/KimKardashian/KimKardashian32.png',
#   './dataset/cropped/KimKardashian/KimKardashian33.png',
#   './dataset/cropped/KimKardashian/KimKardashian34.png',
#   './dataset/cropped/KimKardashian/KimKardashian35.png',
#   './dataset/cropped/KimKardashian/KimKardashian36.png',
#   './dataset/cropped/KimKardashian/KimKardashian37.png',
#   './dataset/cropped/KimKardashian/KimKardashian38.png',
#   './dataset/cropped/KimKardashian/KimKardashian39.png',
#   './dataset/cropped/KimKardashian/KimKardashian40.png',
#   './dataset/cropped/KimKardashian/KimKardashian41.png',
#   './dataset/cropped/KimKardashian/KimKardashian42.png',
#   './dataset/cropped/KimKardashian/KimKardashian43.png',
#   './dataset/cropped/KimKardashian/KimKardashian44.png',
#   './dataset/cropped/KimKardashian/KimKardashian45.png',
#   './dataset/cropped/KimKardashian/KimKardashian46.png',
#   './dataset/cropped/KimKardashian/KimKardashian47.png',
#   './dataset/cropped/KimKardashian/KimKardashian48.png',
#   './dataset/cropped/KimKardashian/KimKardashian49.png',
#   './dataset/cropped/KimKardashian/KimKardashian50.png',
#   './dataset/cropped/KimKardashian/KimKardashian51.png',
#   './dataset/cropped/KimKardashian/KimKardashian52.png',
#   './dataset/cropped/KimKardashian/KimKardashian53.png',
#   './dataset/cropped/KimKardashian/KimKardashian54.png',
#   './dataset/cropped/KimKardashian/KimKardashian55.png',
#   './dataset/cropped/KimKardashian/KimKardashian56.png',
#   './dataset/cropped/KimKardashian/KimKardashian57.png',
#   './dataset/cropped/KimKardashian/KimKardashian58.png',
#   './dataset/cropped/KimKardashian/KimKardashian59.png',
#   './dataset/cropped/KimKardashian/KimKardashian60.png',
#   './dataset/cropped/KimKardashian/KimKardashian61.png',
#   './dataset/cropped/KimKardashian/KimKardashian62.png',
#   './dataset/cropped/KimKardashian/KimKardashian63.png',
#   './dataset/cropped/KimKardashian/KimKardashian64.png',
#   './dataset/cropped/KimKardashian/KimKardashian65.png',
#   './dataset/cropped/KimKardashian/KimKardashian66.png',
#   './dataset/cropped/KimKardashian/KimKardashian67.png',
#   './dataset/cropped/KimKardashian/KimKardashian68.png',
#   './dataset/cropped/KimKardashian/KimKardashian69.png',
#   './dataset/cropped/KimKardashian/KimKardashian70.png',
#   './dataset/cropped/KimKardashian/KimKardashian71.png',
#   './dataset/cropped/KimKardashian/KimKardashian72.png',
#   './dataset/cropped/KimKardashian/KimKardashian73.png',
#   './dataset/cropped/KimKardashian/KimKardashian74.png',
#   './dataset/cropped/KimKardashian/KimKardashian75.png',
#   './dataset/cropped/KimKardashian/KimKardashian76.png',
#   './dataset/cropped/KimKardashian/KimKardashian77.png',
#   './dataset/cropped/KimKardashian/KimKardashian78.png',
#   './dataset/cropped/KimKardashian/KimKardashian79.png',
#   './dataset/cropped/KimKardashian/KimKardashian80.png',
#   './dataset/cropped/KimKardashian/KimKardashian81.png',
#   './dataset/cropped/KimKardashian/KimKardashian82.png',
#   './dataset/cropped/KimKardashian/KimKardashian83.png',
#   './dataset/cropped/KimKardashian/KimKardashian84.png',
#   './dataset/cropped/KimKardashian/KimKardashian85.png',
#   './dataset/cropped/KimKardashian/KimKardashian86.png',
#   './dataset/cropped/KimKardashian/KimKardashian87.png',
#   './dataset/cropped/KimKardashian/KimKardashian88.png',
#   './dataset/cropped/KimKardashian/KimKardashian89.png',
#   './dataset/cropped/KimKardashian/KimKardashian90.png',
#   './dataset/cropped/KimKardashian/KimKardashian91.png',
#   './dataset/cropped/KimKardashian/KimKardashian92.png',
#   './dataset/cropped/KimKardashian/KimKardashian93.png',
#   './dataset/cropped/KimKardashian/KimKardashian94.png',
#   './dataset/cropped/KimKardashian/KimKardashian95.png',
#   './dataset/cropped/KimKardashian/KimKardashian96.png',
#   './dataset/cropped/KimKardashian/KimKardashian97.png',
#   './dataset/cropped/KimKardashian/KimKardashian98.png',
#   './dataset/cropped/KimKardashian/KimKardashian99.png',
#   './dataset/cropped/KimKardashian/KimKardashian100.png',
#   './dataset/cropped/KimKardashian/KimKardashian101.png',
#   './dataset/cropped/KimKardashian/KimKardashian102.png',
#   './dataset/cropped/KimKardashian/KimKardashian103.png',
#   './dataset/cropped/KimKardashian/KimKardashian104.png',
#   './dataset/cropped/KimKardashian/KimKardashian105.png',
#   './dataset/cropped/KimKardashian/KimKardashian106.png',
#   './dataset/cropped/KimKardashian/KimKardashian107.png'],
#  'Beyonce': ['./dataset/cropped/Beyonce/Beyonce1.png',
#   './dataset/cropped/Beyonce/Beyonce2.png',
#   './dataset/cropped/Beyonce/Beyonce3.png',
#   './dataset/cropped/Beyonce/Beyonce4.png',
#   './dataset/cropped/Beyonce/Beyonce5.png',
#   './dataset/cropped/Beyonce/Beyonce6.png',
#   './dataset/cropped/Beyonce/Beyonce7.png',
#   './dataset/cropped/Beyonce/Beyonce8.png',
#   './dataset/cropped/Beyonce/Beyonce9.png',
#   './dataset/cropped/Beyonce/Beyonce10.png',
#   './dataset/cropped/Beyonce/Beyonce11.png',
#   './dataset/cropped/Beyonce/Beyonce12.png',
#   './dataset/cropped/Beyonce/Beyonce13.png',
#   './dataset/cropped/Beyonce/Beyonce14.png',
#   './dataset/cropped/Beyonce/Beyonce15.png',
#   './dataset/cropped/Beyonce/Beyonce16.png',
#   './dataset/cropped/Beyonce/Beyonce17.png',
#   './dataset/cropped/Beyonce/Beyonce18.png',
#   './dataset/cropped/Beyonce/Beyonce19.png',
#   './dataset/cropped/Beyonce/Beyonce20.png',
#   './dataset/cropped/Beyonce/Beyonce21.png',
#   './dataset/cropped/Beyonce/Beyonce22.png',
#   './dataset/cropped/Beyonce/Beyonce23.png',
#   './dataset/cropped/Beyonce/Beyonce24.png',
#   './dataset/cropped/Beyonce/Beyonce25.png',
#   './dataset/cropped/Beyonce/Beyonce26.png',
#   './dataset/cropped/Beyonce/Beyonce27.png',
#   './dataset/cropped/Beyonce/Beyonce28.png',
#   './dataset/cropped/Beyonce/Beyonce29.png',
#   './dataset/cropped/Beyonce/Beyonce30.png',
#   './dataset/cropped/Beyonce/Beyonce31.png',
#   './dataset/cropped/Beyonce/Beyonce32.png',
#   './dataset/cropped/Beyonce/Beyonce33.png',
#   './dataset/cropped/Beyonce/Beyonce34.png',
#   './dataset/cropped/Beyonce/Beyonce35.png',
#   './dataset/cropped/Beyonce/Beyonce36.png',
#   './dataset/cropped/Beyonce/Beyonce37.png',
#   './dataset/cropped/Beyonce/Beyonce38.png',
#   './dataset/cropped/Beyonce/Beyonce39.png',
#   './dataset/cropped/Beyonce/Beyonce40.png',
#   './dataset/cropped/Beyonce/Beyonce41.png',
#   './dataset/cropped/Beyonce/Beyonce42.png',
#   './dataset/cropped/Beyonce/Beyonce43.png',
#   './dataset/cropped/Beyonce/Beyonce44.png',
#   './dataset/cropped/Beyonce/Beyonce45.png',
#   './dataset/cropped/Beyonce/Beyonce46.png',
#   './dataset/cropped/Beyonce/Beyonce47.png',
#   './dataset/cropped/Beyonce/Beyonce48.png',
#   './dataset/cropped/Beyonce/Beyonce49.png',
#   './dataset/cropped/Beyonce/Beyonce50.png',
#   './dataset/cropped/Beyonce/Beyonce51.png',
#   './dataset/cropped/Beyonce/Beyonce52.png',
#   './dataset/cropped/Beyonce/Beyonce53.png',
#   './dataset/cropped/Beyonce/Beyonce54.png',
#   './dataset/cropped/Beyonce/Beyonce55.png',
#   './dataset/cropped/Beyonce/Beyonce56.png',
#   './dataset/cropped/Beyonce/Beyonce57.png',
#   './dataset/cropped/Beyonce/Beyonce58.png',
#   './dataset/cropped/Beyonce/Beyonce59.png',
#   './dataset/cropped/Beyonce/Beyonce60.png',
#   './dataset/cropped/Beyonce/Beyonce61.png',
#   './dataset/cropped/Beyonce/Beyonce62.png',
#   './dataset/cropped/Beyonce/Beyonce63.png',
#   './dataset/cropped/Beyonce/Beyonce64.png'],
#  'Cardi_B': ['./dataset/cropped/Cardi_B/Cardi_B1.png',
#   './dataset/cropped/Cardi_B/Cardi_B2.png',
#   './dataset/cropped/Cardi_B/Cardi_B3.png',
#   './dataset/cropped/Cardi_B/Cardi_B4.png',
#   './dataset/cropped/Cardi_B/Cardi_B5.png',
#   './dataset/cropped/Cardi_B/Cardi_B6.png',
#   './dataset/cropped/Cardi_B/Cardi_B7.png',
#   './dataset/cropped/Cardi_B/Cardi_B8.png',
#   './dataset/cropped/Cardi_B/Cardi_B9.png',
#   './dataset/cropped/Cardi_B/Cardi_B10.png',
#   './dataset/cropped/Cardi_B/Cardi_B11.png',
#   './dataset/cropped/Cardi_B/Cardi_B12.png',
#   './dataset/cropped/Cardi_B/Cardi_B13.png',
#   './dataset/cropped/Cardi_B/Cardi_B14.png',
#   './dataset/cropped/Cardi_B/Cardi_B15.png',
#   './dataset/cropped/Cardi_B/Cardi_B16.png',
#   './dataset/cropped/Cardi_B/Cardi_B17.png',
#   './dataset/cropped/Cardi_B/Cardi_B18.png',
#   './dataset/cropped/Cardi_B/Cardi_B19.png',
#   './dataset/cropped/Cardi_B/Cardi_B20.png',
#   './dataset/cropped/Cardi_B/Cardi_B21.png',
#   './dataset/cropped/Cardi_B/Cardi_B22.png',
#   './dataset/cropped/Cardi_B/Cardi_B23.png',
#   './dataset/cropped/Cardi_B/Cardi_B24.png',
#   './dataset/cropped/Cardi_B/Cardi_B25.png',
#   './dataset/cropped/Cardi_B/Cardi_B26.png',
#   './dataset/cropped/Cardi_B/Cardi_B27.png',
#   './dataset/cropped/Cardi_B/Cardi_B28.png',
#   './dataset/cropped/Cardi_B/Cardi_B29.png',
#   './dataset/cropped/Cardi_B/Cardi_B30.png',
#   './dataset/cropped/Cardi_B/Cardi_B31.png',
#   './dataset/cropped/Cardi_B/Cardi_B32.png',
#   './dataset/cropped/Cardi_B/Cardi_B33.png',
#   './dataset/cropped/Cardi_B/Cardi_B34.png',
#   './dataset/cropped/Cardi_B/Cardi_B35.png',
#   './dataset/cropped/Cardi_B/Cardi_B36.png',
#   './dataset/cropped/Cardi_B/Cardi_B37.png',
#   './dataset/cropped/Cardi_B/Cardi_B38.png',
#   './dataset/cropped/Cardi_B/Cardi_B39.png',
#   './dataset/cropped/Cardi_B/Cardi_B40.png',
#   './dataset/cropped/Cardi_B/Cardi_B41.png',
#   './dataset/cropped/Cardi_B/Cardi_B42.png',
#   './dataset/cropped/Cardi_B/Cardi_B43.png',
#   './dataset/cropped/Cardi_B/Cardi_B44.png',
#   './dataset/cropped/Cardi_B/Cardi_B45.png',
#   './dataset/cropped/Cardi_B/Cardi_B46.png',
#   './dataset/cropped/Cardi_B/Cardi_B47.png',
#   './dataset/cropped/Cardi_B/Cardi_B48.png',
#   './dataset/cropped/Cardi_B/Cardi_B49.png',
#   './dataset/cropped/Cardi_B/Cardi_B50.png',
#   './dataset/cropped/Cardi_B/Cardi_B51.png',
#   './dataset/cropped/Cardi_B/Cardi_B52.png',
#   './dataset/cropped/Cardi_B/Cardi_B53.png',
#   './dataset/cropped/Cardi_B/Cardi_B54.png',
#   './dataset/cropped/Cardi_B/Cardi_B55.png',
#   './dataset/cropped/Cardi_B/Cardi_B56.png',
#   './dataset/cropped/Cardi_B/Cardi_B57.png',
#   './dataset/cropped/Cardi_B/Cardi_B58.png',
#   './dataset/cropped/Cardi_B/Cardi_B59.png',
#   './dataset/cropped/Cardi_B/Cardi_B60.png',
#   './dataset/cropped/Cardi_B/Cardi_B61.png',
#   './dataset/cropped/Cardi_B/Cardi_B62.png',
#   './dataset/cropped/Cardi_B/Cardi_B63.png',
#   './dataset/cropped/Cardi_B/Cardi_B64.png',
#   './dataset/cropped/Cardi_B/Cardi_B65.png',
#   './dataset/cropped/Cardi_B/Cardi_B66.png',
#   './dataset/cropped/Cardi_B/Cardi_B67.png',
#   './dataset/cropped/Cardi_B/Cardi_B68.png',
#   './dataset/cropped/Cardi_B/Cardi_B69.png',
#   './dataset/cropped/Cardi_B/Cardi_B70.png',
#   './dataset/cropped/Cardi_B/Cardi_B71.png',
#   './dataset/cropped/Cardi_B/Cardi_B72.png'],
#  'KanyeWest': ['./dataset/cropped/KanyeWest/KanyeWest1.png',
#   './dataset/cropped/KanyeWest/KanyeWest2.png',
#   './dataset/cropped/KanyeWest/KanyeWest3.png',
#   './dataset/cropped/KanyeWest/KanyeWest4.png',
#   './dataset/cropped/KanyeWest/KanyeWest5.png',
#   './dataset/cropped/KanyeWest/KanyeWest6.png',
#   './dataset/cropped/KanyeWest/KanyeWest7.png',
#   './dataset/cropped/KanyeWest/KanyeWest8.png',
#   './dataset/cropped/KanyeWest/KanyeWest9.png',
#   './dataset/cropped/KanyeWest/KanyeWest10.png',
#   './dataset/cropped/KanyeWest/KanyeWest11.png',
#   './dataset/cropped/KanyeWest/KanyeWest12.png',
#   './dataset/cropped/KanyeWest/KanyeWest13.png',
#   './dataset/cropped/KanyeWest/KanyeWest14.png',
#   './dataset/cropped/KanyeWest/KanyeWest15.png',
#   './dataset/cropped/KanyeWest/KanyeWest16.png',
#   './dataset/cropped/KanyeWest/KanyeWest17.png',
#   './dataset/cropped/KanyeWest/KanyeWest18.png',
#   './dataset/cropped/KanyeWest/KanyeWest19.png',
#   './dataset/cropped/KanyeWest/KanyeWest20.png',
#   './dataset/cropped/KanyeWest/KanyeWest21.png',
#   './dataset/cropped/KanyeWest/KanyeWest22.png',
#   './dataset/cropped/KanyeWest/KanyeWest23.png',
#   './dataset/cropped/KanyeWest/KanyeWest24.png',
#   './dataset/cropped/KanyeWest/KanyeWest25.png',
#   './dataset/cropped/KanyeWest/KanyeWest26.png',
#   './dataset/cropped/KanyeWest/KanyeWest27.png',
#   './dataset/cropped/KanyeWest/KanyeWest28.png',
#   './dataset/cropped/KanyeWest/KanyeWest29.png',
#   './dataset/cropped/KanyeWest/KanyeWest30.png',
#   './dataset/cropped/KanyeWest/KanyeWest31.png',
#   './dataset/cropped/KanyeWest/KanyeWest32.png',
#   './dataset/cropped/KanyeWest/KanyeWest33.png',
#   './dataset/cropped/KanyeWest/KanyeWest34.png',
#   './dataset/cropped/KanyeWest/KanyeWest35.png',
#   './dataset/cropped/KanyeWest/KanyeWest36.png',
#   './dataset/cropped/KanyeWest/KanyeWest37.png',
#   './dataset/cropped/KanyeWest/KanyeWest38.png',
#   './dataset/cropped/KanyeWest/KanyeWest39.png',
#   './dataset/cropped/KanyeWest/KanyeWest40.png',
#   './dataset/cropped/KanyeWest/KanyeWest41.png',
#   './dataset/cropped/KanyeWest/KanyeWest42.png',
#   './dataset/cropped/KanyeWest/KanyeWest43.png',
#   './dataset/cropped/KanyeWest/KanyeWest44.png',
#   './dataset/cropped/KanyeWest/KanyeWest45.png',
#   './dataset/cropped/KanyeWest/KanyeWest46.png',
#   './dataset/cropped/KanyeWest/KanyeWest47.png',
#   './dataset/cropped/KanyeWest/KanyeWest48.png',
#   './dataset/cropped/KanyeWest/KanyeWest49.png',
#   './dataset/cropped/KanyeWest/KanyeWest50.png',
#   './dataset/cropped/KanyeWest/KanyeWest51.png',
#   './dataset/cropped/KanyeWest/KanyeWest52.png',
#   './dataset/cropped/KanyeWest/KanyeWest53.png',
#   './dataset/cropped/KanyeWest/KanyeWest54.png',
#   './dataset/cropped/KanyeWest/KanyeWest55.png',
#   './dataset/cropped/KanyeWest/KanyeWest56.png',
#   './dataset/cropped/KanyeWest/KanyeWest57.png',
#   './dataset/cropped/KanyeWest/KanyeWest58.png',
#   './dataset/cropped/KanyeWest/KanyeWest59.png',
#   './dataset/cropped/KanyeWest/KanyeWest60.png',
#   './dataset/cropped/KanyeWest/KanyeWest61.png',
#   './dataset/cropped/KanyeWest/KanyeWest62.png',
#   './dataset/cropped/KanyeWest/KanyeWest63.png',
#   './dataset/cropped/KanyeWest/KanyeWest64.png',
#   './dataset/cropped/KanyeWest/KanyeWest65.png',
#   './dataset/cropped/KanyeWest/KanyeWest66.png',
#   './dataset/cropped/KanyeWest/KanyeWest67.png',
#   './dataset/cropped/KanyeWest/KanyeWest68.png',
#   './dataset/cropped/KanyeWest/KanyeWest69.png',
#   './dataset/cropped/KanyeWest/KanyeWest70.png',
#   './dataset/cropped/KanyeWest/KanyeWest71.png'],
#  'cropped': []}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Zendaya': 0,
#  'BillieEilish ': 1,
#  'LebronJames': 2,
#  'DonaldTrump': 3,
#  'WillSmith': 4,
#  'KimKardashian': 5,
#  'Beyonce': 6,
#  'Cardi_B': 7,
#  'KanyeWest': 8,
#  'cropped': 9}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
len(X)
# Out:
# 691

# %%
X[0]
# Out:
# array([[213],
#        [200],
#        [202],
#        ...,
#        [246],
#        [243],
#        [ 56]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (691, 4096)

# %%
X[0]
# Out:
# array([213., 200., 202., ..., 246., 243.,  56.])

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Zendaya': ['./dataset/cropped/Zendaya/Zendaya118.png',
#   './dataset/cropped/Zendaya/Zendaya23.png',
#   './dataset/cropped/Zendaya/Zendaya37.png',
#   './dataset/cropped/Zendaya/Zendaya36.png',
#   './dataset/cropped/Zendaya/Zendaya22.png',
#   './dataset/cropped/Zendaya/Zendaya119.png',
#   './dataset/cropped/Zendaya/Zendaya34.png',
#   './dataset/cropped/Zendaya/Zendaya20.png',
#   './dataset/cropped/Zendaya/Zendaya21.png',
#   './dataset/cropped/Zendaya/Zendaya35.png',
#   './dataset/cropped/Zendaya/Zendaya19.png',
#   './dataset/cropped/Zendaya/Zendaya31.png',
#   './dataset/cropped/Zendaya/Zendaya25.png',
#   './dataset/cropped/Zendaya/Zendaya24.png',
#   './dataset/cropped/Zendaya/Zendaya30.png',
#   './dataset/cropped/Zendaya/Zendaya18.png',
#   './dataset/cropped/Zendaya/Zendaya109.png',
#   './dataset/cropped/Zendaya/Zendaya26.png',
#   './dataset/cropped/Zendaya/Zendaya32.png',
#   './dataset/cropped/Zendaya/Zendaya33.png',
#   './dataset/cropped/Zendaya/Zendaya27.png',
#   './dataset/cropped/Zendaya/Zendaya120.png',
#   './dataset/cropped/Zendaya/Zendaya108.png',
#   './dataset/cropped/Zendaya/Zendaya6.png',
#   './dataset/cropped/Zendaya/Zendaya40.png',
#   './dataset/cropped/Zendaya/Zendaya54.png',
#   './dataset/cropped/Zendaya/Zendaya68.png',
#   './dataset/cropped/Zendaya/Zendaya83.png',
#   './dataset/cropped/Zendaya/Zendaya97.png',
#   './dataset/cropped/Zendaya/Zendaya96.png',
#   './dataset/cropped/Zendaya/Zendaya82.png',
#   './dataset/cropped/Zendaya/Zendaya69.png',
#   './dataset/cropped/Zendaya/Zendaya55.png',
#   './dataset/cropped/Zendaya/Zendaya41.png',
#   './dataset/cropped/Zendaya/Zendaya7.png',
#   './dataset/cropped/Zendaya/Zendaya5.png',
#   './dataset/cropped/Zendaya/Zendaya57.png',
#   './dataset/cropped/Zendaya/Zendaya43.png',
#   './dataset/cropped/Zendaya/Zendaya94.png',
#   './dataset/cropped/Zendaya/Zendaya80.png',
#   './dataset/cropped/Zendaya/Zendaya81.png',
#   './dataset/cropped/Zendaya/Zendaya95.png',
#   './dataset/cropped/Zendaya/Zendaya42.png',
#   './dataset/cropped/Zendaya/Zendaya56.png',
#   './dataset/cropped/Zendaya/Zendaya4.png',
#   './dataset/cropped/Zendaya/Zendaya52.png',
#   './dataset/cropped/Zendaya/Zendaya46.png',
#   './dataset/cropped/Zendaya/Zendaya91.png',
#   './dataset/cropped/Zendaya/Zendaya85.png',
#   './dataset/cropped/Zendaya/Zendaya84.png',
#   './dataset/cropped/Zendaya/Zendaya90.png',
#   './dataset/cropped/Zendaya/Zendaya47.png',
#   './dataset/cropped/Zendaya/Zendaya53.png',
#   './dataset/cropped/Zendaya/Zendaya1.png',
#   './dataset/cropped/Zendaya/Zendaya3.png',
#   './dataset/cropped/Zendaya/Zendaya79.png',
#   './dataset/cropped/Zendaya/Zendaya45.png',
#   './dataset/cropped/Zendaya/Zendaya51.png',
#   './dataset/cropped/Zendaya/Zendaya86.png',
#   './dataset/cropped/Zendaya/Zendaya92.png',
#   './dataset/cropped/Zendaya/Zendaya93.png',
#   './dataset/cropped/Zendaya/Zendaya87.png',
#   './dataset/cropped/Zendaya/Zendaya50.png',
#   './dataset/cropped/Zendaya/Zendaya44.png',
#   './dataset/cropped/Zendaya/Zendaya78.png',
#   './dataset/cropped/Zendaya/Zendaya2.png',
#   './dataset/cropped/Zendaya/Zendaya61.png',
#   './dataset/cropped/Zendaya/Zendaya75.png',
#   './dataset/cropped/Zendaya/Zendaya49.png',
#   './dataset/cropped/Zendaya/Zendaya48.png',
#   './dataset/cropped/Zendaya/Zendaya74.png',
#   './dataset/cropped/Zendaya/Zendaya60.png',
#   './dataset/cropped/Zendaya/Zendaya76.png',
#   './dataset/cropped/Zendaya/Zendaya62.png',
#   './dataset/cropped/Zendaya/Zendaya89.png',
#   './dataset/cropped/Zendaya/Zendaya88.png',
#   './dataset/cropped/Zendaya/Zendaya63.png',
#   './dataset/cropped/Zendaya/Zendaya77.png',
#   './dataset/cropped/Zendaya/Zendaya9.png',
#   './dataset/cropped/Zendaya/Zendaya73.png',
#   './dataset/cropped/Zendaya/Zendaya67.png',
#   './dataset/cropped/Zendaya/Zendaya98.png',
#   './dataset/cropped/Zendaya/Zendaya99.png',
#   './dataset/cropped/Zendaya/Zendaya66.png',
#   './dataset/cropped/Zendaya/Zendaya72.png',
#   './dataset/cropped/Zendaya/Zendaya8.png',
#   './dataset/cropped/Zendaya/Zendaya58.png',
#   './dataset/cropped/Zendaya/Zendaya64.png',
#   './dataset/cropped/Zendaya/Zendaya70.png',
#   './dataset/cropped/Zendaya/Zendaya71.png',
#   './dataset/cropped/Zendaya/Zendaya65.png',
#   './dataset/cropped/Zendaya/Zendaya59.png',
#   './dataset/cropped/Zendaya/Zendaya105.png',
#   './dataset/cropped/Zendaya/Zendaya111.png',
#   './dataset/cropped/Zendaya/Zendaya16.png',
#   './dataset/cropped/Zendaya/Zendaya17.png',
#   './dataset/cropped/Zendaya/Zendaya110.png',
#   './dataset/cropped/Zendaya/Zendaya104.png',
#   './dataset/cropped/Zendaya/Zendaya112.png',
#   './dataset/cropped/Zendaya/Zendaya106.png',
#   './dataset/cropped/Zendaya/Zendaya15.png',
#   './dataset/cropped/Zendaya/Zendaya29.png',
#   './dataset/cropped/Zendaya/Zendaya28.png',
#   './dataset/cropped/Zendaya/Zendaya14.png',
#   './dataset/cropped/Zendaya/Zendaya107.png',
#   './dataset/cropped/Zendaya/Zendaya113.png',
#   './dataset/cropped/Zendaya/Zendaya117.png',
#   './dataset/cropped/Zendaya/Zendaya103.png',
#   './dataset/cropped/Zendaya/Zendaya38.png',
#   './dataset/cropped/Zendaya/Zendaya10.png',
#   './dataset/cropped/Zendaya/Zendaya11.png',
#   './dataset/cropped/Zendaya/Zendaya39.png',
#   './dataset/cropped/Zendaya/Zendaya102.png',
#   './dataset/cropped/Zendaya/Zendaya116.png',
#   './dataset/cropped/Zendaya/Zendaya100.png',
#   './dataset/cropped/Zendaya/Zendaya114.png',
#   './dataset/cropped/Zendaya/Zendaya13.png',
#   './dataset/cropped/Zendaya/Zendaya12.png',
#   './dataset/cropped/Zendaya/Zendaya115.png',
#   './dataset/cropped/Zendaya/Zendaya101.png'],
#  'BillieEilish ': ['./dataset/cropped/BillieEilish /BillieEilish 17.png',
#   './dataset/cropped/BillieEilish /BillieEilish 1.png',
#   './dataset/cropped/BillieEilish /BillieEilish 16.png',
#   './dataset/cropped/BillieEilish /BillieEilish 14.png',
#   './dataset/cropped/BillieEilish /BillieEilish 28.png',
#   './dataset/cropped/BillieEilish /BillieEilish 3.png',
#   './dataset/cropped/BillieEilish /BillieEilish 2.png',
#   './dataset/cropped/BillieEilish /BillieEilish 29.png',
#   './dataset/cropped/BillieEilish /BillieEilish 15.png',
#   './dataset/cropped/BillieEilish /BillieEilish 11.png',
#   './dataset/cropped/BillieEilish /BillieEilish 6.png',
#   './dataset/cropped/BillieEilish /BillieEilish 7.png',
#   './dataset/cropped/BillieEilish /BillieEilish 10.png',
#   './dataset/cropped/BillieEilish /BillieEilish 12.png',
#   './dataset/cropped/BillieEilish /BillieEilish 5.png',
#   './dataset/cropped/BillieEilish /BillieEilish 4.png',
#   './dataset/cropped/BillieEilish /BillieEilish 13.png',
#   './dataset/cropped/BillieEilish /BillieEilish 36.png',
#   './dataset/cropped/BillieEilish /BillieEilish 22.png',
#   './dataset/cropped/BillieEilish /BillieEilish 9.png',
#   './dataset/cropped/BillieEilish /BillieEilish 8.png',
#   './dataset/cropped/BillieEilish /BillieEilish 23.png',
#   './dataset/cropped/BillieEilish /BillieEilish 37.png',
#   './dataset/cropped/BillieEilish /BillieEilish 21.png',
#   './dataset/cropped/BillieEilish /BillieEilish 35.png',
#   './dataset/cropped/BillieEilish /BillieEilish 34.png',
#   './dataset/cropped/BillieEilish /BillieEilish 20.png',
#   './dataset/cropped/BillieEilish /BillieEilish 18.png',
#   './dataset/cropped/BillieEilish /BillieEilish 24.png',
#   './dataset/cropped/BillieEilish /BillieEilish 30.png',
#   './dataset/cropped/BillieEilish /BillieEilish 31.png',
#   './dataset/cropped/BillieEilish /BillieEilish 25.png',
#   './dataset/cropped/BillieEilish /BillieEilish 19.png',
#   './dataset/cropped/BillieEilish /BillieEilish 33.png',
#   './dataset/cropped/BillieEilish /BillieEilish 27.png',
#   './dataset/cropped/BillieEilish /BillieEilish 26.png',
#   './dataset/cropped/BillieEilish /BillieEilish 32.png'],
#  'LebronJames': ['./dataset/cropped/LebronJames/LebronJames16.png',
#   './dataset/cropped/LebronJames/LebronJames17.png',
#   './dataset/cropped/LebronJames/LebronJames15.png',
#   './dataset/cropped/LebronJames/LebronJames29.png',
#   './dataset/cropped/LebronJames/LebronJames28.png',
#   './dataset/cropped/LebronJames/LebronJames14.png',
#   './dataset/cropped/LebronJames/LebronJames10.png',
#   './dataset/cropped/LebronJames/LebronJames11.png',
#   './dataset/cropped/LebronJames/LebronJames13.png',
#   './dataset/cropped/LebronJames/LebronJames12.png',
#   './dataset/cropped/LebronJames/LebronJames8.png',
#   './dataset/cropped/LebronJames/LebronJames9.png',
#   './dataset/cropped/LebronJames/LebronJames2.png',
#   './dataset/cropped/LebronJames/LebronJames3.png',
#   './dataset/cropped/LebronJames/LebronJames1.png',
#   './dataset/cropped/LebronJames/LebronJames4.png',
#   './dataset/cropped/LebronJames/LebronJames5.png',
#   './dataset/cropped/LebronJames/LebronJames7.png',
#   './dataset/cropped/LebronJames/LebronJames6.png',
#   './dataset/cropped/LebronJames/LebronJames23.png',
#   './dataset/cropped/LebronJames/LebronJames36.png',
#   './dataset/cropped/LebronJames/LebronJames22.png',
#   './dataset/cropped/LebronJames/LebronJames34.png',
#   './dataset/cropped/LebronJames/LebronJames20.png',
#   './dataset/cropped/LebronJames/LebronJames21.png',
#   './dataset/cropped/LebronJames/LebronJames35.png',
#   './dataset/cropped/LebronJames/LebronJames19.png',
#   './dataset/cropped/LebronJames/LebronJames31.png',
#   './dataset/cropped/LebronJames/LebronJames25.png',
#   './dataset/cropped/LebronJames/LebronJames24.png',
#   './dataset/cropped/LebronJames/LebronJames30.png',
#   './dataset/cropped/LebronJames/LebronJames18.png',
#   './dataset/cropped/LebronJames/LebronJames26.png',
#   './dataset/cropped/LebronJames/LebronJames32.png',
#   './dataset/cropped/LebronJames/LebronJames33.png',
#   './dataset/cropped/LebronJames/LebronJames27.png'],
#  'DonaldTrump': ['./dataset/cropped/DonaldTrump/DonaldTrump38.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump10.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump11.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump39.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump13.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump12.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump16.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump17.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump15.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump29.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump28.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump14.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump8.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump49.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump48.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump9.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump7.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump52.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump46.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump47.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump6.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump4.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump45.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump51.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump50.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump44.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump5.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump1.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump40.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump41.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump2.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump43.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump42.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump3.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump19.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump31.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump25.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump24.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump30.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump18.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump26.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump32.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump33.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump27.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump23.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump37.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump36.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump22.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump34.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump20.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump21.png',
#   './dataset/cropped/DonaldTrump/DonaldTrump35.png'],
#  'WillSmith': ['./dataset/cropped/WillSmith/WillSmith16.png',
#   './dataset/cropped/WillSmith/WillSmith17.png',
#   './dataset/cropped/WillSmith/WillSmith15.png',
#   './dataset/cropped/WillSmith/WillSmith29.png',
#   './dataset/cropped/WillSmith/WillSmith28.png',
#   './dataset/cropped/WillSmith/WillSmith14.png',
#   './dataset/cropped/WillSmith/WillSmith38.png',
#   './dataset/cropped/WillSmith/WillSmith10.png',
#   './dataset/cropped/WillSmith/WillSmith11.png',
#   './dataset/cropped/WillSmith/WillSmith39.png',
#   './dataset/cropped/WillSmith/WillSmith13.png',
#   './dataset/cropped/WillSmith/WillSmith12.png',
#   './dataset/cropped/WillSmith/WillSmith119.png',
#   './dataset/cropped/WillSmith/WillSmith131.png',
#   './dataset/cropped/WillSmith/WillSmith125.png',
#   './dataset/cropped/WillSmith/WillSmith75.png',
#   './dataset/cropped/WillSmith/WillSmith61.png',
#   './dataset/cropped/WillSmith/WillSmith49.png',
#   './dataset/cropped/WillSmith/WillSmith48.png',
#   './dataset/cropped/WillSmith/WillSmith60.png',
#   './dataset/cropped/WillSmith/WillSmith74.png',
#   './dataset/cropped/WillSmith/WillSmith124.png',
#   './dataset/cropped/WillSmith/WillSmith130.png',
#   './dataset/cropped/WillSmith/WillSmith118.png',
#   './dataset/cropped/WillSmith/WillSmith126.png',
#   './dataset/cropped/WillSmith/WillSmith132.png',
#   './dataset/cropped/WillSmith/WillSmith89.png',
#   './dataset/cropped/WillSmith/WillSmith62.png',
#   './dataset/cropped/WillSmith/WillSmith76.png',
#   './dataset/cropped/WillSmith/WillSmith77.png',
#   './dataset/cropped/WillSmith/WillSmith63.png',
#   './dataset/cropped/WillSmith/WillSmith88.png',
#   './dataset/cropped/WillSmith/WillSmith127.png',
#   './dataset/cropped/WillSmith/WillSmith123.png',
#   './dataset/cropped/WillSmith/WillSmith9.png',
#   './dataset/cropped/WillSmith/WillSmith98.png',
#   './dataset/cropped/WillSmith/WillSmith67.png',
#   './dataset/cropped/WillSmith/WillSmith73.png',
#   './dataset/cropped/WillSmith/WillSmith72.png',
#   './dataset/cropped/WillSmith/WillSmith66.png',
#   './dataset/cropped/WillSmith/WillSmith99.png',
#   './dataset/cropped/WillSmith/WillSmith8.png',
#   './dataset/cropped/WillSmith/WillSmith122.png',
#   './dataset/cropped/WillSmith/WillSmith120.png',
#   './dataset/cropped/WillSmith/WillSmith108.png',
#   './dataset/cropped/WillSmith/WillSmith58.png',
#   './dataset/cropped/WillSmith/WillSmith70.png',
#   './dataset/cropped/WillSmith/WillSmith64.png',
#   './dataset/cropped/WillSmith/WillSmith65.png',
#   './dataset/cropped/WillSmith/WillSmith71.png',
#   './dataset/cropped/WillSmith/WillSmith59.png',
#   './dataset/cropped/WillSmith/WillSmith109.png',
#   './dataset/cropped/WillSmith/WillSmith121.png',
#   './dataset/cropped/WillSmith/WillSmith6.png',
#   './dataset/cropped/WillSmith/WillSmith110.png',
#   './dataset/cropped/WillSmith/WillSmith104.png',
#   './dataset/cropped/WillSmith/WillSmith97.png',
#   './dataset/cropped/WillSmith/WillSmith83.png',
#   './dataset/cropped/WillSmith/WillSmith54.png',
#   './dataset/cropped/WillSmith/WillSmith40.png',
#   './dataset/cropped/WillSmith/WillSmith68.png',
#   './dataset/cropped/WillSmith/WillSmith69.png',
#   './dataset/cropped/WillSmith/WillSmith41.png',
#   './dataset/cropped/WillSmith/WillSmith55.png',
#   './dataset/cropped/WillSmith/WillSmith82.png',
#   './dataset/cropped/WillSmith/WillSmith96.png',
#   './dataset/cropped/WillSmith/WillSmith105.png',
#   './dataset/cropped/WillSmith/WillSmith111.png',
#   './dataset/cropped/WillSmith/WillSmith7.png',
#   './dataset/cropped/WillSmith/WillSmith5.png',
#   './dataset/cropped/WillSmith/WillSmith107.png',
#   './dataset/cropped/WillSmith/WillSmith113.png',
#   './dataset/cropped/WillSmith/WillSmith80.png',
#   './dataset/cropped/WillSmith/WillSmith94.png',
#   './dataset/cropped/WillSmith/WillSmith43.png',
#   './dataset/cropped/WillSmith/WillSmith57.png',
#   './dataset/cropped/WillSmith/WillSmith56.png',
#   './dataset/cropped/WillSmith/WillSmith42.png',
#   './dataset/cropped/WillSmith/WillSmith95.png',
#   './dataset/cropped/WillSmith/WillSmith81.png',
#   './dataset/cropped/WillSmith/WillSmith112.png',
#   './dataset/cropped/WillSmith/WillSmith106.png',
#   './dataset/cropped/WillSmith/WillSmith4.png',
#   './dataset/cropped/WillSmith/WillSmith102.png',
#   './dataset/cropped/WillSmith/WillSmith116.png',
#   './dataset/cropped/WillSmith/WillSmith85.png',
#   './dataset/cropped/WillSmith/WillSmith91.png',
#   './dataset/cropped/WillSmith/WillSmith46.png',
#   './dataset/cropped/WillSmith/WillSmith52.png',
#   './dataset/cropped/WillSmith/WillSmith53.png',
#   './dataset/cropped/WillSmith/WillSmith47.png',
#   './dataset/cropped/WillSmith/WillSmith90.png',
#   './dataset/cropped/WillSmith/WillSmith84.png',
#   './dataset/cropped/WillSmith/WillSmith1.png',
#   './dataset/cropped/WillSmith/WillSmith117.png',
#   './dataset/cropped/WillSmith/WillSmith103.png',
#   './dataset/cropped/WillSmith/WillSmith115.png',
#   './dataset/cropped/WillSmith/WillSmith101.png',
#   './dataset/cropped/WillSmith/WillSmith129.png',
#   './dataset/cropped/WillSmith/WillSmith3.png',
#   './dataset/cropped/WillSmith/WillSmith92.png',
#   './dataset/cropped/WillSmith/WillSmith86.png',
#   './dataset/cropped/WillSmith/WillSmith79.png',
#   './dataset/cropped/WillSmith/WillSmith51.png',
#   './dataset/cropped/WillSmith/WillSmith45.png',
#   './dataset/cropped/WillSmith/WillSmith44.png',
#   './dataset/cropped/WillSmith/WillSmith50.png',
#   './dataset/cropped/WillSmith/WillSmith78.png',
#   './dataset/cropped/WillSmith/WillSmith87.png',
#   './dataset/cropped/WillSmith/WillSmith93.png',
#   './dataset/cropped/WillSmith/WillSmith2.png',
#   './dataset/cropped/WillSmith/WillSmith128.png',
#   './dataset/cropped/WillSmith/WillSmith100.png',
#   './dataset/cropped/WillSmith/WillSmith114.png',
#   './dataset/cropped/WillSmith/WillSmith37.png',
#   './dataset/cropped/WillSmith/WillSmith23.png',
#   './dataset/cropped/WillSmith/WillSmith22.png',
#   './dataset/cropped/WillSmith/WillSmith36.png',
#   './dataset/cropped/WillSmith/WillSmith20.png',
#   './dataset/cropped/WillSmith/WillSmith34.png',
#   './dataset/cropped/WillSmith/WillSmith35.png',
#   './dataset/cropped/WillSmith/WillSmith21.png',
#   './dataset/cropped/WillSmith/WillSmith19.png',
#   './dataset/cropped/WillSmith/WillSmith25.png',
#   './dataset/cropped/WillSmith/WillSmith31.png',
#   './dataset/cropped/WillSmith/WillSmith30.png',
#   './dataset/cropped/WillSmith/WillSmith24.png',
#   './dataset/cropped/WillSmith/WillSmith18.png',
#   './dataset/cropped/WillSmith/WillSmith32.png',
#   './dataset/cropped/WillSmith/WillSmith26.png',
#   './dataset/cropped/WillSmith/WillSmith27.png',
#   './dataset/cropped/WillSmith/WillSmith33.png'],
#  'KimKardashian': ['./dataset/cropped/KimKardashian/KimKardashian81.png',
#   './dataset/cropped/KimKardashian/KimKardashian95.png',
#   './dataset/cropped/KimKardashian/KimKardashian42.png',
#   './dataset/cropped/KimKardashian/KimKardashian56.png',
#   './dataset/cropped/KimKardashian/KimKardashian1.png',
#   './dataset/cropped/KimKardashian/KimKardashian57.png',
#   './dataset/cropped/KimKardashian/KimKardashian43.png',
#   './dataset/cropped/KimKardashian/KimKardashian94.png',
#   './dataset/cropped/KimKardashian/KimKardashian80.png',
#   './dataset/cropped/KimKardashian/KimKardashian96.png',
#   './dataset/cropped/KimKardashian/KimKardashian82.png',
#   './dataset/cropped/KimKardashian/KimKardashian55.png',
#   './dataset/cropped/KimKardashian/KimKardashian41.png',
#   './dataset/cropped/KimKardashian/KimKardashian69.png',
#   './dataset/cropped/KimKardashian/KimKardashian2.png',
#   './dataset/cropped/KimKardashian/KimKardashian3.png',
#   './dataset/cropped/KimKardashian/KimKardashian68.png',
#   './dataset/cropped/KimKardashian/KimKardashian40.png',
#   './dataset/cropped/KimKardashian/KimKardashian54.png',
#   './dataset/cropped/KimKardashian/KimKardashian83.png',
#   './dataset/cropped/KimKardashian/KimKardashian97.png',
#   './dataset/cropped/KimKardashian/KimKardashian93.png',
#   './dataset/cropped/KimKardashian/KimKardashian87.png',
#   './dataset/cropped/KimKardashian/KimKardashian78.png',
#   './dataset/cropped/KimKardashian/KimKardashian50.png',
#   './dataset/cropped/KimKardashian/KimKardashian44.png',
#   './dataset/cropped/KimKardashian/KimKardashian7.png',
#   './dataset/cropped/KimKardashian/KimKardashian6.png',
#   './dataset/cropped/KimKardashian/KimKardashian45.png',
#   './dataset/cropped/KimKardashian/KimKardashian51.png',
#   './dataset/cropped/KimKardashian/KimKardashian79.png',
#   './dataset/cropped/KimKardashian/KimKardashian86.png',
#   './dataset/cropped/KimKardashian/KimKardashian92.png',
#   './dataset/cropped/KimKardashian/KimKardashian84.png',
#   './dataset/cropped/KimKardashian/KimKardashian90.png',
#   './dataset/cropped/KimKardashian/KimKardashian47.png',
#   './dataset/cropped/KimKardashian/KimKardashian53.png',
#   './dataset/cropped/KimKardashian/KimKardashian4.png',
#   './dataset/cropped/KimKardashian/KimKardashian5.png',
#   './dataset/cropped/KimKardashian/KimKardashian52.png',
#   './dataset/cropped/KimKardashian/KimKardashian46.png',
#   './dataset/cropped/KimKardashian/KimKardashian91.png',
#   './dataset/cropped/KimKardashian/KimKardashian85.png',
#   './dataset/cropped/KimKardashian/KimKardashian21.png',
#   './dataset/cropped/KimKardashian/KimKardashian35.png',
#   './dataset/cropped/KimKardashian/KimKardashian34.png',
#   './dataset/cropped/KimKardashian/KimKardashian20.png',
#   './dataset/cropped/KimKardashian/KimKardashian36.png',
#   './dataset/cropped/KimKardashian/KimKardashian22.png',
#   './dataset/cropped/KimKardashian/KimKardashian23.png',
#   './dataset/cropped/KimKardashian/KimKardashian37.png',
#   './dataset/cropped/KimKardashian/KimKardashian33.png',
#   './dataset/cropped/KimKardashian/KimKardashian27.png',
#   './dataset/cropped/KimKardashian/KimKardashian26.png',
#   './dataset/cropped/KimKardashian/KimKardashian32.png',
#   './dataset/cropped/KimKardashian/KimKardashian18.png',
#   './dataset/cropped/KimKardashian/KimKardashian24.png',
#   './dataset/cropped/KimKardashian/KimKardashian30.png',
#   './dataset/cropped/KimKardashian/KimKardashian31.png',
#   './dataset/cropped/KimKardashian/KimKardashian25.png',
#   './dataset/cropped/KimKardashian/KimKardashian19.png',
#   './dataset/cropped/KimKardashian/KimKardashian103.png',
#   './dataset/cropped/KimKardashian/KimKardashian14.png',
#   './dataset/cropped/KimKardashian/KimKardashian28.png',
#   './dataset/cropped/KimKardashian/KimKardashian29.png',
#   './dataset/cropped/KimKardashian/KimKardashian15.png',
#   './dataset/cropped/KimKardashian/KimKardashian102.png',
#   './dataset/cropped/KimKardashian/KimKardashian100.png',
#   './dataset/cropped/KimKardashian/KimKardashian17.png',
#   './dataset/cropped/KimKardashian/KimKardashian16.png',
#   './dataset/cropped/KimKardashian/KimKardashian101.png',
#   './dataset/cropped/KimKardashian/KimKardashian105.png',
#   './dataset/cropped/KimKardashian/KimKardashian12.png',
#   './dataset/cropped/KimKardashian/KimKardashian13.png',
#   './dataset/cropped/KimKardashian/KimKardashian104.png',
#   './dataset/cropped/KimKardashian/KimKardashian106.png',
#   './dataset/cropped/KimKardashian/KimKardashian39.png',
#   './dataset/cropped/KimKardashian/KimKardashian11.png',
#   './dataset/cropped/KimKardashian/KimKardashian10.png',
#   './dataset/cropped/KimKardashian/KimKardashian38.png',
#   './dataset/cropped/KimKardashian/KimKardashian107.png',
#   './dataset/cropped/KimKardashian/KimKardashian88.png',
#   './dataset/cropped/KimKardashian/KimKardashian63.png',
#   './dataset/cropped/KimKardashian/KimKardashian77.png',
#   './dataset/cropped/KimKardashian/KimKardashian8.png',
#   './dataset/cropped/KimKardashian/KimKardashian9.png',
#   './dataset/cropped/KimKardashian/KimKardashian76.png',
#   './dataset/cropped/KimKardashian/KimKardashian62.png',
#   './dataset/cropped/KimKardashian/KimKardashian89.png',
#   './dataset/cropped/KimKardashian/KimKardashian74.png',
#   './dataset/cropped/KimKardashian/KimKardashian60.png',
#   './dataset/cropped/KimKardashian/KimKardashian48.png',
#   './dataset/cropped/KimKardashian/KimKardashian49.png',
#   './dataset/cropped/KimKardashian/KimKardashian61.png',
#   './dataset/cropped/KimKardashian/KimKardashian75.png',
#   './dataset/cropped/KimKardashian/KimKardashian59.png',
#   './dataset/cropped/KimKardashian/KimKardashian71.png',
#   './dataset/cropped/KimKardashian/KimKardashian65.png',
#   './dataset/cropped/KimKardashian/KimKardashian64.png',
#   './dataset/cropped/KimKardashian/KimKardashian70.png',
#   './dataset/cropped/KimKardashian/KimKardashian58.png',
#   './dataset/cropped/KimKardashian/KimKardashian99.png',
#   './dataset/cropped/KimKardashian/KimKardashian66.png',
#   './dataset/cropped/KimKardashian/KimKardashian72.png',
#   './dataset/cropped/KimKardashian/KimKardashian73.png',
#   './dataset/cropped/KimKardashian/KimKardashian67.png',
#   './dataset/cropped/KimKardashian/KimKardashian98.png'],
#  'Beyonce': ['./dataset/cropped/Beyonce/Beyonce29.png',
#   './dataset/cropped/Beyonce/Beyonce4.png',
#   './dataset/cropped/Beyonce/Beyonce15.png',
#   './dataset/cropped/Beyonce/Beyonce5.png',
#   './dataset/cropped/Beyonce/Beyonce14.png',
#   './dataset/cropped/Beyonce/Beyonce28.png',
#   './dataset/cropped/Beyonce/Beyonce16.png',
#   './dataset/cropped/Beyonce/Beyonce7.png',
#   './dataset/cropped/Beyonce/Beyonce17.png',
#   './dataset/cropped/Beyonce/Beyonce6.png',
#   './dataset/cropped/Beyonce/Beyonce2.png',
#   './dataset/cropped/Beyonce/Beyonce13.png',
#   './dataset/cropped/Beyonce/Beyonce3.png',
#   './dataset/cropped/Beyonce/Beyonce12.png',
#   './dataset/cropped/Beyonce/Beyonce10.png',
#   './dataset/cropped/Beyonce/Beyonce1.png',
#   './dataset/cropped/Beyonce/Beyonce38.png',
#   './dataset/cropped/Beyonce/Beyonce39.png',
#   './dataset/cropped/Beyonce/Beyonce11.png',
#   './dataset/cropped/Beyonce/Beyonce62.png',
#   './dataset/cropped/Beyonce/Beyonce63.png',
#   './dataset/cropped/Beyonce/Beyonce49.png',
#   './dataset/cropped/Beyonce/Beyonce61.png',
#   './dataset/cropped/Beyonce/Beyonce60.png',
#   './dataset/cropped/Beyonce/Beyonce48.png',
#   './dataset/cropped/Beyonce/Beyonce64.png',
#   './dataset/cropped/Beyonce/Beyonce58.png',
#   './dataset/cropped/Beyonce/Beyonce59.png',
#   './dataset/cropped/Beyonce/Beyonce43.png',
#   './dataset/cropped/Beyonce/Beyonce57.png',
#   './dataset/cropped/Beyonce/Beyonce56.png',
#   './dataset/cropped/Beyonce/Beyonce42.png',
#   './dataset/cropped/Beyonce/Beyonce54.png',
#   './dataset/cropped/Beyonce/Beyonce40.png',
#   './dataset/cropped/Beyonce/Beyonce41.png',
#   './dataset/cropped/Beyonce/Beyonce55.png',
#   './dataset/cropped/Beyonce/Beyonce51.png',
#   './dataset/cropped/Beyonce/Beyonce45.png',
#   './dataset/cropped/Beyonce/Beyonce44.png',
#   './dataset/cropped/Beyonce/Beyonce50.png',
#   './dataset/cropped/Beyonce/Beyonce46.png',
#   './dataset/cropped/Beyonce/Beyonce52.png',
#   './dataset/cropped/Beyonce/Beyonce53.png',
#   './dataset/cropped/Beyonce/Beyonce47.png',
#   './dataset/cropped/Beyonce/Beyonce20.png',
#   './dataset/cropped/Beyonce/Beyonce34.png',
#   './dataset/cropped/Beyonce/Beyonce35.png',
#   './dataset/cropped/Beyonce/Beyonce21.png',
#   './dataset/cropped/Beyonce/Beyonce37.png',
#   './dataset/cropped/Beyonce/Beyonce23.png',
#   './dataset/cropped/Beyonce/Beyonce22.png',
#   './dataset/cropped/Beyonce/Beyonce36.png',
#   './dataset/cropped/Beyonce/Beyonce32.png',
#   './dataset/cropped/Beyonce/Beyonce26.png',
#   './dataset/cropped/Beyonce/Beyonce27.png',
#   './dataset/cropped/Beyonce/Beyonce33.png',
#   './dataset/cropped/Beyonce/Beyonce25.png',
#   './dataset/cropped/Beyonce/Beyonce31.png',
#   './dataset/cropped/Beyonce/Beyonce8.png',
#   './dataset/cropped/Beyonce/Beyonce19.png',
#   './dataset/cropped/Beyonce/Beyonce9.png',
#   './dataset/cropped/Beyonce/Beyonce18.png',
#   './dataset/cropped/Beyonce/Beyonce30.png',
#   './dataset/cropped/Beyonce/Beyonce24.png'],
#  'Cardi_B': ['./dataset/cropped/Cardi_B/Cardi_B19.png',
#   './dataset/cropped/Cardi_B/Cardi_B31.png',
#   './dataset/cropped/Cardi_B/Cardi_B25.png',
#   './dataset/cropped/Cardi_B/Cardi_B24.png',
#   './dataset/cropped/Cardi_B/Cardi_B30.png',
#   './dataset/cropped/Cardi_B/Cardi_B18.png',
#   './dataset/cropped/Cardi_B/Cardi_B26.png',
#   './dataset/cropped/Cardi_B/Cardi_B32.png',
#   './dataset/cropped/Cardi_B/Cardi_B33.png',
#   './dataset/cropped/Cardi_B/Cardi_B27.png',
#   './dataset/cropped/Cardi_B/Cardi_B23.png',
#   './dataset/cropped/Cardi_B/Cardi_B37.png',
#   './dataset/cropped/Cardi_B/Cardi_B36.png',
#   './dataset/cropped/Cardi_B/Cardi_B22.png',
#   './dataset/cropped/Cardi_B/Cardi_B34.png',
#   './dataset/cropped/Cardi_B/Cardi_B20.png',
#   './dataset/cropped/Cardi_B/Cardi_B21.png',
#   './dataset/cropped/Cardi_B/Cardi_B35.png',
#   './dataset/cropped/Cardi_B/Cardi_B52.png',
#   './dataset/cropped/Cardi_B/Cardi_B46.png',
#   './dataset/cropped/Cardi_B/Cardi_B47.png',
#   './dataset/cropped/Cardi_B/Cardi_B53.png',
#   './dataset/cropped/Cardi_B/Cardi_B8.png',
#   './dataset/cropped/Cardi_B/Cardi_B45.png',
#   './dataset/cropped/Cardi_B/Cardi_B51.png',
#   './dataset/cropped/Cardi_B/Cardi_B50.png',
#   './dataset/cropped/Cardi_B/Cardi_B44.png',
#   './dataset/cropped/Cardi_B/Cardi_B9.png',
#   './dataset/cropped/Cardi_B/Cardi_B40.png',
#   './dataset/cropped/Cardi_B/Cardi_B54.png',
#   './dataset/cropped/Cardi_B/Cardi_B68.png',
#   './dataset/cropped/Cardi_B/Cardi_B69.png',
#   './dataset/cropped/Cardi_B/Cardi_B55.png',
#   './dataset/cropped/Cardi_B/Cardi_B41.png',
#   './dataset/cropped/Cardi_B/Cardi_B57.png',
#   './dataset/cropped/Cardi_B/Cardi_B43.png',
#   './dataset/cropped/Cardi_B/Cardi_B42.png',
#   './dataset/cropped/Cardi_B/Cardi_B56.png',
#   './dataset/cropped/Cardi_B/Cardi_B2.png',
#   './dataset/cropped/Cardi_B/Cardi_B67.png',
#   './dataset/cropped/Cardi_B/Cardi_B66.png',
#   './dataset/cropped/Cardi_B/Cardi_B72.png',
#   './dataset/cropped/Cardi_B/Cardi_B3.png',
#   './dataset/cropped/Cardi_B/Cardi_B1.png',
#   './dataset/cropped/Cardi_B/Cardi_B58.png',
#   './dataset/cropped/Cardi_B/Cardi_B64.png',
#   './dataset/cropped/Cardi_B/Cardi_B70.png',
#   './dataset/cropped/Cardi_B/Cardi_B71.png',
#   './dataset/cropped/Cardi_B/Cardi_B65.png',
#   './dataset/cropped/Cardi_B/Cardi_B59.png',
#   './dataset/cropped/Cardi_B/Cardi_B4.png',
#   './dataset/cropped/Cardi_B/Cardi_B61.png',
#   './dataset/cropped/Cardi_B/Cardi_B49.png',
#   './dataset/cropped/Cardi_B/Cardi_B48.png',
#   './dataset/cropped/Cardi_B/Cardi_B60.png',
#   './dataset/cropped/Cardi_B/Cardi_B5.png',
#   './dataset/cropped/Cardi_B/Cardi_B7.png',
#   './dataset/cropped/Cardi_B/Cardi_B62.png',
#   './dataset/cropped/Cardi_B/Cardi_B63.png',
#   './dataset/cropped/Cardi_B/Cardi_B6.png',
#   './dataset/cropped/Cardi_B/Cardi_B38.png',
#   './dataset/cropped/Cardi_B/Cardi_B10.png',
#   './dataset/cropped/Cardi_B/Cardi_B11.png',
#   './dataset/cropped/Cardi_B/Cardi_B39.png',
#   './dataset/cropped/Cardi_B/Cardi_B13.png',
#   './dataset/cropped/Cardi_B/Cardi_B12.png',
#   './dataset/cropped/Cardi_B/Cardi_B16.png',
#   './dataset/cropped/Cardi_B/Cardi_B17.png',
#   './dataset/cropped/Cardi_B/Cardi_B15.png',
#   './dataset/cropped/Cardi_B/Cardi_B29.png',
#   './dataset/cropped/Cardi_B/Cardi_B28.png',
#   './dataset/cropped/Cardi_B/Cardi_B14.png'],
#  'KanyeWest': ['./dataset/cropped/KanyeWest/KanyeWest44.png',
#   './dataset/cropped/KanyeWest/KanyeWest50.png',
#   './dataset/cropped/KanyeWest/KanyeWest51.png',
#   './dataset/cropped/KanyeWest/KanyeWest45.png',
#   './dataset/cropped/KanyeWest/KanyeWest53.png',
#   './dataset/cropped/KanyeWest/KanyeWest47.png',
#   './dataset/cropped/KanyeWest/KanyeWest46.png',
#   './dataset/cropped/KanyeWest/KanyeWest52.png',
#   './dataset/cropped/KanyeWest/KanyeWest56.png',
#   './dataset/cropped/KanyeWest/KanyeWest42.png',
#   './dataset/cropped/KanyeWest/KanyeWest43.png',
#   './dataset/cropped/KanyeWest/KanyeWest57.png',
#   './dataset/cropped/KanyeWest/KanyeWest69.png',
#   './dataset/cropped/KanyeWest/KanyeWest41.png',
#   './dataset/cropped/KanyeWest/KanyeWest55.png',
#   './dataset/cropped/KanyeWest/KanyeWest54.png',
#   './dataset/cropped/KanyeWest/KanyeWest40.png',
#   './dataset/cropped/KanyeWest/KanyeWest68.png',
#   './dataset/cropped/KanyeWest/KanyeWest27.png',
#   './dataset/cropped/KanyeWest/KanyeWest33.png',
#   './dataset/cropped/KanyeWest/KanyeWest4.png',
#   './dataset/cropped/KanyeWest/KanyeWest5.png',
#   './dataset/cropped/KanyeWest/KanyeWest32.png',
#   './dataset/cropped/KanyeWest/KanyeWest26.png',
#   './dataset/cropped/KanyeWest/KanyeWest30.png',
#   './dataset/cropped/KanyeWest/KanyeWest24.png',
#   './dataset/cropped/KanyeWest/KanyeWest18.png',
#   './dataset/cropped/KanyeWest/KanyeWest7.png',
#   './dataset/cropped/KanyeWest/KanyeWest6.png',
#   './dataset/cropped/KanyeWest/KanyeWest19.png',
#   './dataset/cropped/KanyeWest/KanyeWest25.png',
#   './dataset/cropped/KanyeWest/KanyeWest31.png',
#   './dataset/cropped/KanyeWest/KanyeWest35.png',
#   './dataset/cropped/KanyeWest/KanyeWest21.png',
#   './dataset/cropped/KanyeWest/KanyeWest2.png',
#   './dataset/cropped/KanyeWest/KanyeWest3.png',
#   './dataset/cropped/KanyeWest/KanyeWest20.png',
#   './dataset/cropped/KanyeWest/KanyeWest34.png',
#   './dataset/cropped/KanyeWest/KanyeWest22.png',
#   './dataset/cropped/KanyeWest/KanyeWest36.png',
#   './dataset/cropped/KanyeWest/KanyeWest1.png',
#   './dataset/cropped/KanyeWest/KanyeWest37.png',
#   './dataset/cropped/KanyeWest/KanyeWest23.png',
#   './dataset/cropped/KanyeWest/KanyeWest12.png',
#   './dataset/cropped/KanyeWest/KanyeWest13.png',
#   './dataset/cropped/KanyeWest/KanyeWest11.png',
#   './dataset/cropped/KanyeWest/KanyeWest39.png',
#   './dataset/cropped/KanyeWest/KanyeWest38.png',
#   './dataset/cropped/KanyeWest/KanyeWest10.png',
#   './dataset/cropped/KanyeWest/KanyeWest28.png',
#   './dataset/cropped/KanyeWest/KanyeWest14.png',
#   './dataset/cropped/KanyeWest/KanyeWest15.png',
#   './dataset/cropped/KanyeWest/KanyeWest29.png',
#   './dataset/cropped/KanyeWest/KanyeWest17.png',
#   './dataset/cropped/KanyeWest/KanyeWest8.png',
#   './dataset/cropped/KanyeWest/KanyeWest9.png',
#   './dataset/cropped/KanyeWest/KanyeWest16.png',
#   './dataset/cropped/KanyeWest/KanyeWest65.png',
#   './dataset/cropped/KanyeWest/KanyeWest71.png',
#   './dataset/cropped/KanyeWest/KanyeWest59.png',
#   './dataset/cropped/KanyeWest/KanyeWest58.png',
#   './dataset/cropped/KanyeWest/KanyeWest70.png',
#   './dataset/cropped/KanyeWest/KanyeWest64.png',
#   './dataset/cropped/KanyeWest/KanyeWest66.png',
#   './dataset/cropped/KanyeWest/KanyeWest67.png',
#   './dataset/cropped/KanyeWest/KanyeWest63.png',
#   './dataset/cropped/KanyeWest/KanyeWest62.png',
#   './dataset/cropped/KanyeWest/KanyeWest48.png',
#   './dataset/cropped/KanyeWest/KanyeWest60.png',
#   './dataset/cropped/KanyeWest/KanyeWest61.png',
#   './dataset/cropped/KanyeWest/KanyeWest49.png']}

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8208092485549133

# %%
len(X_test)
# Out:
# 173

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.87      0.75        30
#            1       0.75      0.86      0.80         7
#            2       0.75      1.00      0.86         6
#            3       1.00      0.73      0.85        15
#            4       0.89      0.89      0.89        36
#            5       0.83      0.89      0.86        27
#            6       0.93      0.59      0.72        22
#            7       0.69      0.82      0.75        11
#            8       1.00      0.79      0.88        19
#
#     accuracy                           0.82       173
#    macro avg       0.83      0.83      0.82       173
# weighted avg       0.84      0.82      0.82       173

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.833981
# 1        random_forest    0.658234
# 2  logistic_regression    0.804966
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.838150289017341

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7109826589595376

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7976878612716763

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[26,  0,  0,  0,  0,  1,  0,  3,  0],
#        [ 0,  4,  0,  0,  0,  1,  1,  1,  0],
#        [ 0,  0,  6,  0,  0,  0,  0,  0,  0],
#        [ 3,  0,  0, 12,  0,  0,  0,  0,  0],
#        [ 0,  1,  1,  0, 33,  0,  0,  0,  1],
#        [ 1,  1,  0,  0,  0, 24,  0,  1,  0],
#        [ 3,  1,  0,  0,  2,  1, 14,  1,  0],
#        [ 1,  0,  0,  0,  0,  1,  0,  9,  0],
#        [ 0,  0,  1,  0,  0,  0,  0,  1, 17]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Zendaya': 0,
#  'BillieEilish ': 1,
#  'LebronJames': 2,
#  'DonaldTrump': 3,
#  'WillSmith': 4,
#  'KimKardashian': 5,
#  'Beyonce': 6,
#  'Cardi_B': 7,
#  'KanyeWest': 8,
#  'cropped': 9}

# %%
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
